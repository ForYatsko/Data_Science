# %%
import importlib
import model_training
importlib.reload(model_training)
import visualization
importlib.reload(visualization)
import anomaly_detection
importlib.reload(anomaly_detection)
# Out:
# <module 'anomaly_detection' from '/content/anomaly_detection.py'>

# %%
import numpy as np
import logging
from logging_config import setup_logging
from data_processing import load_data, describe_data, preprocess_data, ensure_directories, eda
from visualization import plot_predictions, visualize_statistics, visualize_metrics, plot_anomalies_with_model
from model_training import train_models, train_arima, train_lstm, create_ensemble
from anomaly_detection import detect_anomalies
from improvements import preprocess_with_anomalies, weighted_ensemble
from sklearn.model_selection import train_test_split
import matplotlib
# %matplotlib inline

def main():
    # Настройка логирования
    logger = setup_logging(log_file="my_log.log", log_level=logging.DEBUG)
    logger.info("Логирование настроено.")
    ensure_directories()

    # Этап 1: Загрузка данных
    try:
        logger.info("Загрузка данных...")
        df = load_data("data/coin_Bitcoin.csv")
        logger.info("Данные успешно загружены.")
    except Exception as e:
        logger.error(f"Ошибка при загрузке данных: {e}")
        return

    # Этап 2: Предварительная обработка данных
    try:
        logger.info("Выполнение предварительной обработки данных...")
        df = preprocess_data(df)  # Обработка данных
        logger.info("Предварительная обработка завершена.")
    except Exception as e:
        logger.error(f"Ошибка при обработке данных: {e}")
        return

    # Этап 3: Анализ обработанных данных (EDA)
    try:
        logger.info("Выполнение анализа обработанных данных (EDA)...")
        eda(df)  # Анализ данных после обработки
        logger.info("EDA завершен.")
    except Exception as e:
        logger.error(f"Ошибка при выполнении EDA: {e}")
        return

    # Этап 4: Описательная статистика
    try:
        logger.info("Выполнение описательной статистики...")
        describe_data(df)
        visualize_statistics(df)
        logger.info("Описательная статистика завершена.")
    except Exception as e:
        logger.error(f"Ошибка при выполнении описательной статистики: {e}")
        return

    # Этап 5: Разделение данных на обучающую и тестовую выборки
    try:
        logger.info("Разделение данных на обучающую и тестовую выборки...")
        X = df[["Close_shift_1", "Close_shift_2", "Close_shift_3"]]
        y = df["Close"]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
        logger.info("Разделение данных завершено.")
    except Exception as e:
        logger.error(f"Ошибка при разделении данных: {e}")
        return

    # Этап 6: Обучение моделей и создание ансамбля
    try:
        logger.info("Обучение моделей...")

        # Обучение XGBoost, LightGBM, CatBoost
        results_ml, metrics_ml = train_models(X_train, y_train, X_test, y_test)

        # Обучение ARIMA
        results_arima, metrics_arima = train_arima(y_train, y_test)

        # Обучение LSTM
        results_lstm, metrics_lstm = train_lstm(X_train, y_train, X_test, y_test)

        # Создание ансамбля
        ensemble_predictions, metrics_ensemble = create_ensemble(
            [results_ml, results_arima, results_lstm], y_test
        )
        logger.info("Ансамбль моделей создан.")

        # Объединение всех метрик
        all_metrics = {
            **metrics_ml,
            **metrics_arima,
            **metrics_lstm,
            **metrics_ensemble
        }
    except Exception as e:
        logger.error(f"Ошибка во время обучения моделей: {e}")
        return


    # Этап 7: Визуализация прогнозов
    try:
        logger.info("Визуализация прогнозов...")
        plot_predictions(
            y_test,
            ensemble_predictions,
            "Прогноз ансамбля моделей",
            "ensemble_predictions.png",
            metrics={key: value['MSE'] for key, value in all_metrics.items() if 'MSE' in value}  # Показ только MSE
        )
        logger.info("Визуализация прогнозов завершена.")
    except Exception as e:
        logger.error(f"Ошибка при визуализации прогнозов: {e}")
        return

    # Этап 8: Поиск и визуализация аномалий
    try:
        logging.info("Поиск аномалий с использованием модуля аномалий...")

        # Установка порога для метода detect_anomalies
        threshold = 1000  # Порог отклонения
        logging.info(f"Используемый порог для аномалий: {threshold}")

        # Поиск аномалий с использованием функции detect_anomalies
        anomalies_series = detect_anomalies(y_test, ensemble_predictions, threshold=threshold)
        anomalies_bool = y_test.index.isin(anomalies_series.index)  # Преобразуем в логический массив
        num_anomalies = len(anomalies_series)  # Количество аномалий

        # Логирование количества аномалий
        logging.info(f"Найдено {num_anomalies} аномалий из {len(y_test)} наблюдений.")

        # Построение графика с аномалиями
        plot_anomalies_with_model(
            y_true=y_test,
            y_pred=ensemble_predictions,
            anomalies=anomalies_bool,
            title="График с аномалиями и моделью",
            filename="anomalies_with_model.png"
        )
        logging.info("Визуализация аномалий завершена.")
    except Exception as e:
        logging.error(f"Ошибка при поиске или визуализации аномалий: {e}")
        raise

if __name__ == "__main__":
    main()
# Out:
# 2025-04-05 00:23:58,011 - INFO - Логгирование настроено. Логи записываются в файл: /content/my_log.log
# 2025-04-05 00:23:58,013 - INFO - Логирование настроено.
# 2025-04-05 00:23:58,015 - INFO - Загрузка данных...
# 2025-04-05 00:23:58,017 - INFO - Загрузка данных...
# 2025-04-05 00:23:58,035 - INFO - Преобразование столбца 'Date' в datetime...
# 2025-04-05 00:23:58,044 - INFO - Данные успешно загружены: 2991 строк, 10 колонок.
# 2025-04-05 00:23:58,054 - INFO - Первые строки датасета:
#    SNo     Name Symbol                Date        High         Low        Open       Close  Volume     Marketcap
# 0    1  Bitcoin    BTC 2013-04-29 23:59:59  147.488007  134.000000  134.444000  144.539993     0.0  1.603769e+09
# 1    2  Bitcoin    BTC 2013-04-30 23:59:59  146.929993  134.050003  144.000000  139.000000     0.0  1.542813e+09
# 2    3  Bitcoin    BTC 2013-05-01 23:59:59  139.889999  107.720001  139.000000  116.989998     0.0  1.298955e+09
# 3    4  Bitcoin    BTC 2013-05-02 23:59:59  125.599998   92.281898  116.379997  105.209999     0.0  1.168517e+09
# 4    5  Bitcoin    BTC 2013-05-03 23:59:59  108.127998   79.099998  106.250000   97.750000     0.0  1.085995e+09
# 2025-04-05 00:23:58,055 - INFO - Данные успешно загружены.
# 2025-04-05 00:23:58,056 - INFO - Выполнение предварительной обработки данных...
# 2025-04-05 00:23:58,057 - INFO - Начало предварительной обработки данных...
# 2025-04-05 00:23:58,058 - INFO - Удаление строк с некорректными датами и сортировка...
# 2025-04-05 00:23:58,066 - INFO - Удаление строк с пропущенными значениями в столбцах: ['Close', 'Volume']...
# 2025-04-05 00:23:58,072 - INFO - Удаление выбросов в столбце 'Volume'...
# 2025-04-05 00:23:58,073 - INFO - Удаление выбросов для столбца 'Volume'...
# 2025-04-05 00:23:58,080 - INFO - Удалено 264 выбросов из столбца 'Volume'.
# 2025-04-05 00:23:58,082 - INFO - Границы выбросов: нижняя = -23804306290.703274, верхняя = 39754823151.17212.
# 2025-04-05 00:23:58,083 - INFO - Тип данных столбца 'Volume' перед фильтрацией: float64
# 2025-04-05 00:23:58,085 - INFO - Количество строк с нулевым 'Volume' до удаления: 242
# 2025-04-05 00:23:58,087 - INFO - Количество NaN значений в 'Volume': 0
# 2025-04-05 00:23:58,094 - INFO - Количество строк с нулевым 'Volume' после удаления: 0
# 2025-04-05 00:23:58,095 - INFO - Размер данных после удаления строк с нулевым 'Volume': (2485, 10)
# 2025-04-05 00:23:58,097 - INFO - Минимум и максимум 'Volume' после удаления: 2857830.0, 39698054597.4259
# 2025-04-05 00:23:58,098 - INFO - Масштабирование данных в столбце 'Volume'...
# 2025-04-05 00:23:58,100 - INFO - Данные в 'Volume' масштабированы до миллиарда единиц.
# 2025-04-05 00:23:58,102 - INFO - Создание лаговых признаков...
# 2025-04-05 00:23:58,109 - INFO - Предварительная обработка завершена.
# 2025-04-05 00:23:58,194 - INFO - Обработанные данные сохранены в output/processed_data/processed_data.csv.
# 2025-04-05 00:23:58,197 - INFO - Предварительная обработка завершена.
# 2025-04-05 00:23:58,198 - INFO - Выполнение анализа обработанных данных (EDA)...
# 2025-04-05 00:23:58,199 - INFO - Начало расширенного EDA...
# 2025-04-05 00:23:58,768 - INFO - График распределения цены закрытия сохранён в output/visualizations/eda_close_distribution.png.
# 2025-04-05 00:23:59,369 - INFO - График распределения объёма торгов сохранён в output/visualizations/eda_volume_distribution.png.
# 2025-04-05 00:24:00,686 - INFO - Корреляционная матрица сохранена в output/visualizations/eda_correlation_matrix.png.
# 2025-04-05 00:24:00,687 - INFO - Агрегация данных по месяцам для графика объёма торгов...
# 2025-04-05 00:24:00,696 - INFO - Первые строки monthly_data:
#      Month    Volume
# 0  2013-12  0.041605
# 1  2014-01  1.153386
# 2  2014-02  1.269686
# 3  2014-03  0.763979
# 4  2014-04  0.789304
# 2025-04-05 00:24:00,697 - INFO - Количество строк в monthly_data: 89
# 2025-04-05 00:24:00,701 - INFO - Минимум, максимум и среднее 'Volume': 0.041605, 767.9275557372354, 194.19285233301957
# 2025-04-05 00:24:00,702 - INFO - Количество строк с нулевым 'Volume': 0
# 2025-04-05 00:24:00,705 - INFO - Примеры строк с нулевым 'Volume':
# Empty DataFrame
# Columns: [SNo, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap, Close_shift_1, Close_shift_2, Close_shift_3, Month]
# Index: []
# 2025-04-05 00:24:00,708 - INFO - Количество строк с нулевым 'Volume' после фильтрации: 0
# 2025-04-05 00:24:00,728 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-04-05 00:24:00,737 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-04-05 00:24:01,481 - INFO - График объёма торгов сохранён в output/visualizations/eda_volume_monthly.png.
# 2025-04-05 00:24:01,483 - INFO - Построение сезонного анализа по месяцам...
# 2025-04-05 00:24:02,011 - INFO - График сезонного анализа по месяцам сохранён в output/visualizations/eda_monthly_avg_close.png.
# 2025-04-05 00:24:02,322 - INFO - График выбросов в цене закрытия сохранён в output/visualizations/eda_close_outliers.png.
# 2025-04-05 00:24:02,323 - INFO - Расширенный EDA успешно завершён.
# 2025-04-05 00:24:02,325 - INFO - EDA завершен.
# 2025-04-05 00:24:02,326 - INFO - Выполнение описательной статистики...
# 2025-04-05 00:24:02,327 - INFO - Описание данных...
# 2025-04-05 00:24:02,377 - INFO - Описательная статистика:
#                SNo                           Date          High           Low  \
# count  2482.000000                           2482   2482.000000   2482.000000
# mean   1495.647059  2017-06-02 15:31:44.882353408   4651.891489   4422.031641
# min     246.000000            2013-12-30 23:59:59    211.731003    171.509995
# 25%     866.250000            2015-09-12 05:59:59    457.440262    444.444244
# 50%    1486.500000            2017-05-24 11:59:59   2230.814941   1982.665039
# 75%    2106.750000            2019-02-03 17:59:59   7949.058615   7530.412820
# max    2991.000000            2021-07-06 23:59:59  57902.592171  56141.906515
# std     731.849194                            NaN   5790.246869   5467.790880
#
#                Open         Close       Volume     Marketcap  Close_shift_1  \
# count   2482.000000   2482.000000  2482.000000  2.482000e+03    2482.000000
# mean    4541.960792   4547.792133     6.963402  7.989031e+10    4534.298924
# min      176.897003    178.102997     0.002858  2.444379e+09     178.102997
# 25%      452.362991    452.135490     0.041417  6.534622e+09     452.135490
# 50%     2048.635010   2062.964966     0.874488  3.371486e+10    2040.034973
# 75%     7713.468119   7745.562500    10.458580  1.355264e+11    7717.964966
# max    57825.862820  56631.077413    39.698055  1.058862e+12   56631.077413
# std     5647.688471   5647.340476    10.329207  1.035092e+11    5616.303450
#
#        Close_shift_2  Close_shift_3
# count    2482.000000    2482.000000
# mean     4520.995873    4507.074556
# min       178.102997     178.102997
# 25%       452.135490     452.135490
# 50%      2018.864990    1993.284973
# 75%      7710.579956    7708.685368
# max     56631.077413   56631.077413
# std      5586.106340    5552.353526
# 2025-04-05 00:24:02,393 - INFO - Среднее значение столбца 'Close': 4547.792132719601
# 2025-04-05 00:24:02,395 - INFO - Максимальное значение столбца 'Close': 56631.07741255
# 2025-04-05 00:24:02,396 - INFO - Минимальное значение столбца 'Close': 178.10299682617188
# 2025-04-05 00:24:02,400 - INFO - Пропущенные значения:
# SNo              0
# Name             0
# Symbol           0
# Date             0
# High             0
# Low              0
# Open             0
# Close            0
# Volume           0
# Marketcap        0
# Close_shift_1    0
# Close_shift_2    0
# Close_shift_3    0
# Month            0
# dtype: int64
# 2025-04-05 00:24:02,402 - INFO - Визуализация распределения данных с гистограммами...
# 2025-04-05 00:24:02,703 - INFO - График для Open сохранен: output/visualizations/Open_distribution.png
# 2025-04-05 00:24:03,173 - INFO - График для High сохранен: output/visualizations/High_distribution.png
# 2025-04-05 00:24:03,647 - INFO - График для Low сохранен: output/visualizations/Low_distribution.png
# 2025-04-05 00:24:04,092 - INFO - График для Close сохранен: output/visualizations/Close_distribution.png
# 2025-04-05 00:24:04,299 - INFO - Описательная статистика завершена.
# 2025-04-05 00:24:04,300 - INFO - Разделение данных на обучающую и тестовую выборки...
# 2025-04-05 00:24:04,306 - INFO - Разделение данных завершено.
# 2025-04-05 00:24:04,307 - INFO - Обучение моделей...
# 2025-04-05 00:24:04,309 - INFO - Обучение моделей машинного обучения...
# 2025-04-05 00:24:04,311 - INFO - Обучение модели: XGBoost...
# 2025-04-05 00:24:05,012 - INFO - XGBoost метрики: {'MSE': 22919638.416584138, 'MAE': 1540.0400795016396, 'R²': 0.5181613953372473, 'MAPE': 7.04392318028516}
# 2025-04-05 00:24:05,014 - INFO - Обучение модели: LightGBM...
# 2025-04-05 00:24:05,428 - INFO - LightGBM метрики: {'MSE': 24866660.514448214, 'MAE': 1536.6086586422045, 'R²': 0.47722923079648616, 'MAPE': 6.506555321466964}
# 2025-04-05 00:24:05,430 - INFO - Обучение модели: CatBoost...
# 2025-04-05 00:24:07,942 - INFO - CatBoost метрики: {'MSE': 22519521.181697737, 'MAE': 1452.3002709002492, 'R²': 0.5265730433159379, 'MAPE': 6.230427549159458}
# 2025-04-05 00:24:07,946 - INFO - Ансамбль ML моделей метрики: {'MSE': 23330205.744472582, 'MAE': 1463.9883302642195, 'R²': 0.5095300554882408, 'MAPE': 6.177105641300564}
# 2025-04-05 00:24:07,955 - INFO - Обучение ARIMA модели...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# 2025-04-05 00:24:08,340 - INFO - ARIMA метрики: {'MSE': 62475958.86002503, 'MAE': 4077.571458019238, 'R²': -0.31342948326357156, 'MAPE': 15.55431465241913}
# 2025-04-05 00:24:08,349 - INFO - Обучение LSTM модели...
# Epoch 1/10
# 63/63 [==============================] - 2s 4ms/step - loss: 10584950.0000
# Epoch 2/10
# 63/63 [==============================] - 0s 5ms/step - loss: 135864.0625
# Epoch 3/10
# 63/63 [==============================] - 0s 5ms/step - loss: 85807.7500
# Epoch 4/10
# 63/63 [==============================] - 0s 5ms/step - loss: 85588.8672
# Epoch 5/10
# 63/63 [==============================] - 0s 5ms/step - loss: 86082.7656
# Epoch 6/10
# 63/63 [==============================] - 0s 5ms/step - loss: 88011.7891
# Epoch 7/10
# 63/63 [==============================] - 0s 5ms/step - loss: 87579.7266
# Epoch 8/10
# 63/63 [==============================] - 0s 4ms/step - loss: 87020.9688
# Epoch 9/10
# 63/63 [==============================] - 0s 5ms/step - loss: 86216.3281
# Epoch 10/10
# 63/63 [==============================] - 0s 5ms/step - loss: 84297.6953
# 16/16 [==============================] - 0s 2ms/step
# 2025-04-05 00:24:15,819 - INFO - LSTM метрики: {'MSE': 2917423.873122343, 'MAE': 471.87105270759804, 'R²': 0.9386671193199139, 'MAPE': 3.192852882199479}
# 2025-04-05 00:24:15,821 - INFO - Создание ансамбля моделей...
# 2025-04-05 00:24:15,828 - INFO - Ансамбль всех моделей метрики: {'MSE': 18969695.452666108, 'MAE': 1817.2038402384119, 'R²': 0.6012008818962753, 'MAPE': 9.93247955133315}
# 2025-04-05 00:24:15,830 - INFO - Ансамбль моделей создан.
# 2025-04-05 00:24:15,832 - INFO - Визуализация прогнозов...
# 2025-04-05 00:24:16,265 - INFO - График сохранён в output/visualizations/ensemble_predictions.png.
# 2025-04-05 00:24:16,267 - INFO - Визуализация прогнозов завершена.
# 2025-04-05 00:24:16,268 - INFO - Поиск аномалий с использованием модуля аномалий...
# 2025-04-05 00:24:16,268 - INFO - Используемый порог для аномалий: 1000
# 2025-04-05 00:24:16,269 - INFO - Поиск аномалий на основе разницы между фактическими и прогнозируемыми значениями...
# 2025-04-05 00:24:16,271 - INFO - Найдено 176 аномалий. Порог: 1000
# 2025-04-05 00:24:16,272 - INFO - Найдено 176 аномалий из 497 наблюдений.
# 2025-04-05 00:24:17,064 - INFO - График сохранён в output/visualizations/anomalies_with_model.png.
# 2025-04-05 00:24:17,066 - INFO - Визуализация аномалий завершена.

# %% [markdown]
# # New Section
